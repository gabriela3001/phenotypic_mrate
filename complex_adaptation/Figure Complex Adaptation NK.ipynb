# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('all_SA_NK1.txt', 'rb') as f:
    all_SA_NK1 = pickle.load(f)
    
with open('all_CA_NK1.txt', 'rb') as f:
    all_CA_NK1 = pickle.load(f) 
    
with open('all_SA_NK3.txt', 'rb') as f:
    all_SA_NK3 = pickle.load(f) 
    
with open('all_CA_NK3.txt', 'rb') as f:
    all_CA_NK3 = pickle.load(f) 
    
with open('all_SA_NK5.txt', 'rb') as f:
    all_SA_NK5 = pickle.load(f) 
    
with open('all_CA_NK5.txt', 'rb') as f:
    all_CA_NK5 = pickle.load(f) 
    
with open('results_aspergillus_CA_SA_confint.txt', 'rb') as f:
    CA_aspergillus, SA_aspergillus = pickle.load(f)

# %%
def confidence_interval(data_array, n):
    return(np.array([1.96*np.sqrt((p*(1-p))/n) for p in data_array]))

# %%
fig, ax = plt.subplots(1,2,figsize = (20,7.5))

ax[0].plot(all_CA_NK3[0], c = 'C0') 
ax[0].plot(all_CA_NK3[0]+confint_CA_NK3_genetic, c = 'C0', alpha = 0.3)
ax[0].plot(all_CA_NK3[0]-confint_CA_NK3_genetic, c = 'C0', alpha = 0.3)
ax[0].plot(all_CA_NK3[1], c = 'C2')
ax[0].plot(all_CA_NK3[1]+confint_CA_NK3_epigenetic, c = 'C2', alpha = 0.3)
ax[0].plot(all_CA_NK3[1]-confint_CA_NK3_epigenetic, c = 'C2', alpha = 0.3)
ax[0].plot(all_CA_NK3[2], c = 'C3')
ax[0].plot(all_CA_NK3[2]+confint_CA_NK3_random, c = 'C3', alpha = 0.3)
ax[0].plot(all_CA_NK3[2]-confint_CA_NK3_random, c = 'C3', alpha = 0.3)

ax[0].plot(np.array(all_SA_NK3[0]), c = 'C0', linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[0])+confint_SA_NK3_genetic, c = 'C0', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[0])-confint_SA_NK3_genetic, c = 'C0', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[1]), c = 'C2', linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[1])+confint_SA_NK3_epigenetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[1])-confint_SA_NK3_epigenetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[2]), c = 'C3', linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[2])+confint_SA_NK3_random, c = 'C3', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK3[2])-confint_SA_NK3_random, c = 'C3', alpha = 0.3, linestyle = ':')

ax[0].set_xticks(np.arange(0,50001,10000))
ax[0].set_xticklabels([format(x, ',') for x in np.arange(0,50001,10000)],fontsize = 16)

ax[1].plot(CA_aspergillus[0][0], c = 'C0', alpha = 0.3)
ax[1].plot(CA_aspergillus[0][1], c = 'C0')
ax[1].plot(CA_aspergillus[0][2], c = 'C0', alpha = 0.3)

ax[1].plot(CA_aspergillus[1][0], c = 'C2', alpha = 0.3)
ax[1].plot(CA_aspergillus[1][1], c = 'C2')
ax[1].plot(CA_aspergillus[1][2], c = 'C2', alpha = 0.3)

ax[1].plot(CA_aspergillus[2][0], c = 'C3', alpha = 0.3)
ax[1].plot(CA_aspergillus[2][1], c = 'C3')
ax[1].plot(CA_aspergillus[2][2], c = 'C3', alpha = 0.3)


ax[1].plot(SA_aspergillus[0][0], c = 'C0', alpha = 0.3, linestyle='dotted')
ax[1].plot(SA_aspergillus[0][1], c = 'C0', linestyle='dotted')
ax[1].plot(SA_aspergillus[0][2], c = 'C0', alpha = 0.3, linestyle='dotted')

ax[1].plot(SA_aspergillus[1][0], c = 'C2', alpha = 0.3, linestyle='dotted')
ax[1].plot(SA_aspergillus[1][1], c = 'C2', linestyle='dotted')
ax[1].plot(SA_aspergillus[1][2], c = 'C2', alpha = 0.3, linestyle='dotted')

ax[1].plot(SA_aspergillus[2][0], c = 'C3', alpha = 0.3, linestyle='dotted')
ax[1].plot(SA_aspergillus[2][1], c = 'C3', linestyle='dotted')
ax[1].plot(SA_aspergillus[2][2], c = 'C3', alpha = 0.3, linestyle='dotted')


ax[1].set_xticks(np.arange(0,50001,10000))
ax[1].set_xticklabels([format(x, ',') for x in np.arange(0,50001,10000)],fontsize = 16)

ax[0].set_xlabel('Generations', fontsize = 22)
ax[1].set_xlabel('Generations', fontsize = 22)
ax[0].set_ylabel('Frequency of Adaptive Genotype', fontsize = 22)

ax[0].set_ylim(-0.05,1.0)
ax[1].set_ylim(-0.05,1.0)

ax[0].set_yticks(np.arange(0,1.1,0.2))
ax[1].set_yticks(np.arange(0,1.1,0.2))

ylabels = [np.round(x, 1) for x in np.arange(0,1.1,0.2)]

ax[0].set_yticklabels(ylabels, fontsize = 18)
ax[1].set_yticklabels(ylabels, fontsize = 18)

plt.tight_layout()

plt.savefig('Complex_Adaptation_both_june.jpg', dpi = 300)

# %%
for i in range(3):
    plt.plot(CA_aspergillus[0][i])

# %%
confint_SA_NK3_epigenetic
# Out:
# array([0.        , 0.        , 0.        , ..., 0.00350335, 0.00350335,
#        0.00350335])

# %%
confint_CA_NK1_genetic = confidence_interval(all_CA_NK1[0], 500)
confint_CA_NK1_epigenetic = confidence_interval(all_CA_NK1[1], 500)
confint_CA_NK1_random = confidence_interval(all_CA_NK1[2], 500)

confint_SA_NK1_genetic = confidence_interval(np.array(all_SA_NK1[0]), 500)
confint_SA_NK1_epigenetic = confidence_interval(np.array(all_SA_NK1[1]), 500)
confint_SA_NK1_random = confidence_interval(np.array(all_SA_NK1[2]), 500)

# %%
confint_CA_NK3_genetic = confidence_interval(all_CA_NK3[0], 500)
confint_CA_NK3_epigenetic = confidence_interval(all_CA_NK3[1], 500)
confint_CA_NK3_random = confidence_interval(all_CA_NK3[2], 500)

confint_SA_NK3_genetic = confidence_interval(np.array(all_SA_NK3[0]), 500)
confint_SA_NK3_epigenetic = confidence_interval(np.array(all_SA_NK3[1]), 500)
confint_SA_NK3_random = confidence_interval(np.array(all_SA_NK3[2]), 500)

# %%
confint_CA_NK5_genetic = confidence_interval(all_CA_NK5[0], 500)
confint_CA_NK5_epigenetic = confidence_interval(all_CA_NK5[1], 500)
confint_CA_NK5_random = confidence_interval(all_CA_NK5[2], 500)

confint_SA_NK5_genetic = confidence_interval(np.array(all_SA_NK5[0]), 500)
confint_SA_NK5_epigenetic = confidence_interval(np.array(all_SA_NK5[1]), 500)
confint_SA_NK5_random = confidence_interval(np.array(all_SA_NK5[2]), 500)

# %%
fig, ax = plt.subplots(1,3,figsize = (15,3.5))

ax[0].plot(all_CA_NK1[0], c = 'C2') 
ax[0].plot(all_CA_NK1[0]+confint_CA_NK1_genetic, c = 'C2', alpha = 0.3)
ax[0].plot(all_CA_NK1[0]-confint_CA_NK1_genetic, c = 'C2', alpha = 0.3)
ax[0].plot(all_CA_NK1[1], c = 'C3')
ax[0].plot(all_CA_NK1[1]+confint_CA_NK1_epigenetic, c = 'C3', alpha = 0.3)
ax[0].plot(all_CA_NK1[1]-confint_CA_NK1_epigenetic, c = 'C3', alpha = 0.3)
ax[0].plot(all_CA_NK1[2], c = 'C1')
ax[0].plot(all_CA_NK1[2]+confint_CA_NK1_random, c = 'C1', alpha = 0.3)
ax[0].plot(all_CA_NK1[2]-confint_CA_NK1_random, c = 'C1', alpha = 0.3)

ax[0].plot(np.array(all_SA_NK1[0]), c = 'C2', linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[0])+confint_SA_NK1_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[0])-confint_SA_NK1_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[1]), c = 'C3', linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[1])+confint_SA_NK1_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[1])-confint_SA_NK1_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[2]), c = 'C1', linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[2])+confint_SA_NK1_random, c = 'C1', alpha = 0.3, linestyle = ':')
ax[0].plot(np.array(all_SA_NK1[2])-confint_SA_NK1_random, c = 'C1', alpha = 0.3, linestyle = ':')

ax[0].set_title('NK Landscape K = 1', fontsize = 14)

ax[1].plot(all_CA_NK3[0], c = 'C2') 
ax[1].plot(all_CA_NK3[0]+confint_CA_NK3_genetic, c = 'C2', alpha = 0.3)
ax[1].plot(all_CA_NK3[0]-confint_CA_NK3_genetic, c = 'C2', alpha = 0.3)
ax[1].plot(all_CA_NK3[1], c = 'C3')
ax[1].plot(all_CA_NK3[1]+confint_CA_NK3_epigenetic, c = 'C3', alpha = 0.3)
ax[1].plot(all_CA_NK3[1]-confint_CA_NK3_epigenetic, c = 'C3', alpha = 0.3)
ax[1].plot(all_CA_NK3[2], c = 'C1')
ax[1].plot(all_CA_NK3[2]+confint_CA_NK3_random, c = 'C1', alpha = 0.3)
ax[1].plot(all_CA_NK3[2]-confint_CA_NK3_random, c = 'C1', alpha = 0.3)

ax[1].plot(np.array(all_SA_NK3[0]), c = 'C2', linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[0])+confint_SA_NK3_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[0])-confint_SA_NK3_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[1]), c = 'C3', linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[1])+confint_SA_NK3_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[1])-confint_SA_NK3_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[2]), c = 'C1', linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[2])+confint_SA_NK3_random, c = 'C1', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[2])-confint_SA_NK3_random, c = 'C1', alpha = 0.3, linestyle = ':')

ax[1].set_title('NK Landscape K = 3', fontsize = 14)

ax[2].plot(all_CA_NK5[0], c = 'C2') 
ax[2].plot(all_CA_NK5[0]+confint_CA_NK5_genetic, c = 'C2', alpha = 0.3)
ax[2].plot(all_CA_NK5[0]-confint_CA_NK5_genetic, c = 'C2', alpha = 0.3)
ax[2].plot(all_CA_NK5[1], c = 'C3')
ax[2].plot(all_CA_NK5[1]+confint_CA_NK5_epigenetic, c = 'C3', alpha = 0.3)
ax[2].plot(all_CA_NK5[1]-confint_CA_NK5_epigenetic, c = 'C3', alpha = 0.3)
ax[2].plot(all_CA_NK5[2], c = 'C1')
ax[2].plot(all_CA_NK5[2]+confint_CA_NK5_random, c = 'C1', alpha = 0.3)
ax[2].plot(all_CA_NK5[2]-confint_CA_NK5_random, c = 'C1', alpha = 0.3)

ax[2].plot(np.array(all_SA_NK5[0]), c = 'C2', linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[0])+confint_SA_NK5_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[0])-confint_SA_NK5_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[1]), c = 'C3', linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[1])+confint_SA_NK5_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[1])-confint_SA_NK5_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[2]), c = 'C1', linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[2])+confint_SA_NK5_random, c = 'C1', alpha = 0.3, linestyle = ':')
ax[2].plot(np.array(all_SA_NK5[2])-confint_SA_NK5_random, c = 'C1', alpha = 0.3, linestyle = ':')

ax[2].set_title('NK Landscape K = 5', fontsize = 14)

ax[0].set_xticks(np.arange(0,50001,10000))
ax[1].set_xticks(np.arange(0,50001,10000))
ax[2].set_xticks(np.arange(0,50001,10000))

ax[0].set_xticklabels([format(x, ',') for x in np.arange(0,50001,10000)])
ax[1].set_xticklabels([format(x, ',') for x in np.arange(0,50001,10000)])
ax[2].set_xticklabels([format(x, ',') for x in np.arange(0,50001,10000)])

ax[0].set_xlabel('Time (generations)', fontsize = 12)
ax[1].set_xlabel('Time (generations)', fontsize = 12)
ax[2].set_xlabel('Time (generations)', fontsize = 12)

ax[0].set_ylabel('% population to reach \n global max', fontsize = 12)
ax[1].set_ylabel('% population to reach \n global max', fontsize = 12)
ax[2].set_ylabel('% population to reach \n global max', fontsize = 12)

plt.tight_layout()

# %%
fig, ax = plt.subplots(1,2, figsize = (20,5))

ax[0].plot(all_CA_NK3[0], c = 'C2') 
ax[0].plot(all_CA_NK3[0]+confint_CA_NK3_genetic, c = 'C2', alpha = 0.3)
ax[0].plot(all_CA_NK3[0]-confint_CA_NK3_genetic, c = 'C2', alpha = 0.3)
ax[0].plot(all_CA_NK3[1], c = 'C3')
ax[0].plot(all_CA_NK3[1]+confint_CA_NK3_epigenetic, c = 'C3', alpha = 0.3)
ax[0].plot(all_CA_NK3[1]-confint_CA_NK3_epigenetic, c = 'C3', alpha = 0.3)
ax[0].plot(all_CA_NK3[2], c = 'C1')
ax[0].plot(all_CA_NK3[2]+confint_CA_NK3_random, c = 'C1', alpha = 0.3)
ax[0].plot(all_CA_NK3[2]-confint_CA_NK3_random, c = 'C1', alpha = 0.3)

ax[1].plot(np.array(all_SA_NK3[0]), c = 'C2', linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[0])+confint_SA_NK3_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[0])-confint_SA_NK3_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[1]), c = 'C3', linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[1])+confint_SA_NK3_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[1])-confint_SA_NK3_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[2]), c = 'C1', linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[2])+confint_SA_NK3_random, c = 'C1', alpha = 0.3, linestyle = ':')
ax[1].plot(np.array(all_SA_NK3[2])-confint_SA_NK3_random, c = 'C1', alpha = 0.3, linestyle = ':')

# %%
plt.plot(all_CA_NK3[0], c = 'C2') 
plt.plot(all_CA_NK3[0]+confint_CA_NK3_genetic, c = 'C2', alpha = 0.3)
plt.plot(all_CA_NK3[0]-confint_CA_NK3_genetic, c = 'C2', alpha = 0.3)
plt.plot(all_CA_NK3[1], c = 'C3')
plt.plot(all_CA_NK3[1]+confint_CA_NK3_epigenetic, c = 'C3', alpha = 0.3)
plt.plot(all_CA_NK3[1]-confint_CA_NK3_epigenetic, c = 'C3', alpha = 0.3)
plt.plot(all_CA_NK3[2], c = 'C1')
plt.plot(all_CA_NK3[2]+confint_CA_NK3_random, c = 'C1', alpha = 0.3)
plt.plot(all_CA_NK3[2]-confint_CA_NK3_random, c = 'C1', alpha = 0.3)

plt.plot(np.array(all_SA_NK3[0]), c = 'C2', linestyle = ':')
plt.plot(np.array(all_SA_NK3[0])+confint_SA_NK3_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
plt.plot(np.array(all_SA_NK3[0])-confint_SA_NK3_genetic, c = 'C2', alpha = 0.3, linestyle = ':')
plt.plot(np.array(all_SA_NK3[1]), c = 'C3', linestyle = ':')
plt.plot(np.array(all_SA_NK3[1])+confint_SA_NK3_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
plt.plot(np.array(all_SA_NK3[1])-confint_SA_NK3_epigenetic, c = 'C3', alpha = 0.3, linestyle = ':')
plt.plot(np.array(all_SA_NK3[2]), c = 'C1', linestyle = ':')
plt.plot(np.array(all_SA_NK3[2])+confint_SA_NK3_random, c = 'C1', alpha = 0.3, linestyle = ':')
plt.plot(np.array(all_SA_NK3[2])-confint_SA_NK3_random, c = 'C1', alpha = 0.3, linestyle = ':')

plt.xticks(np.arange(0,50001,10000),[format(x, ',') for x in np.arange(0,50001,10000)])

plt.xlabel('Generations', fontsize = 13)
plt.ylabel('% population to reach \n global max', fontsize = 13)

plt.savefig('Only_NK3_Complex_Adaptation.jpg', dpi = 400)
